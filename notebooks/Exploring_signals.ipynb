# %% [markdown]
# # Exploring signals (PhysioNet Challenge 2018)
#
# Visualiza EEG crudo (todas las derivaciones EEG, foco en C3-M2 y C4-M1), etiquetas de arousal,
# y etapas de sueño durante un fragmento temporal. Exporta PNGs de resumen y zoom sobre un arousal.
#
# La implementación está en **`src/process.py`**; este notebook solo configura rutas.
#
# **Dependencias**: instala en modo editable desde la raíz del repo (`pip install -e .`) o usa el bootstrap a `src` en la siguiente celda.

# %%
from pathlib import Path
import sys
sys.path.insert(0, '../')

from src.process import run_exploration

# Ruta sin extensión al par tr03-<id>.mat / tr03-<id>-arousal.mat
BASE_PATH = Path("Data/0005/tr03-0005")

run_exploration(BASE_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 10
#       6
#       7 # Ruta sin extensión al par tr03-<id>.mat / tr03-<id>-arousal.mat
#       8 BASE_PATH = Path("Data/0005/tr03-0005")
#       9
# ---> 10 run_exploration(BASE_PATH)
#
# File /app/notebooks/../src/process.py:532, in run_exploration(base_path, patient_label)
#     529 base = Path(base_path)
#     530 base_display = patient_label or base.name
# --> 532 signals, arousals, sleep_stages = load_signals_and_arousals(base, include_sleep_stages=True)
#     534 print(f"\n{'=' * 55}")
#     535 print(f"  Paciente: {base_display}")
#
# File /app/notebooks/../src/process.py:76, in load_signals_and_arousals(base_path, include_sleep_stages)
#      73 arousal_path = Path(str(base) + "-arousal.mat")
#      75 if not mat_path.is_file():
# ---> 76     raise FileNotFoundError(f"Missing signal file: {mat_path}")
#      77 if not arousal_path.is_file():
#      78     raise FileNotFoundError(f"Missing arousal file: {arousal_path}")
#
# FileNotFoundError: Missing signal file: Data/0005/tr03-0005.mat
