# %% [markdown]
# # Exploring signals (PhysioNet Challenge 2018)
#
# Visualiza EEG crudo (todas las derivaciones EEG, foco en C3-M2 y C4-M1), etiquetas de arousal,
# y etapas de sueño durante un fragmento temporal. Exporta PNGs de resumen y zoom sobre un arousal.
#
# La implementación está en **`src/process.py`**; este notebook solo configura rutas.
#
# **Dependencias**: instala en modo editable desde la raíz del repo (`pip install -e .`) o usa el bootstrap a `src` en la siguiente celda.

# %%
from pathlib import Path
import sys
sys.path.insert(0, '../')

from src.viz import run_exploration

# Ruta sin extensión al par tr03-<id>.mat / tr03-<id>-arousal.mat
BASE_PATH = Path("data/raw/tr03-0005/")

run_exploration(BASE_PATH)
# Out:
# data\raw\tr03-0005\tr03-0005.mat data\raw\tr03-0005\tr03-0005-arousal.mat
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\IDMOP0\Documents\master\mHealth-project-code\.venv\Lib\site-packages\scipy\io\matlab\_mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except OSError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\raw\\tr03-0005\\tr03-0005.mat'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 10
#       6
#       7 # Ruta sin extensión al par tr03-<id>.mat / tr03-<id>-arousal.mat
#       8 BASE_PATH = Path("data/raw/tr03-0005/")
#       9
# ---> 10 run_exploration(BASE_PATH)
#
# File c:\Users\IDMOP0\Documents\master\mHealth-project-code\notebooks\..\src\viz.py:198, in run_exploration(base_path, patient_label)
#     195 base = Path(base_path)
#     196 base_display = patient_label or base.name
# --> 198 signals, arousals, sleep_stages = load_signals_and_arousals(base, include_sleep_stages=True)
#     200 print(f"\n{'=' * 55}")
#     201 print(f"  Paciente: {base_display}")
#
# File c:\Users\IDMOP0\Documents\master\mHealth-project-code\notebooks\..\src\utils.py:30, in load_signals_and_arousals(base_path, include_sleep_stages, downsample_factor)
#      27 arousal_path = base / f"{base.name}-arousal.mat"
#      28 print(mat_path, arousal_path)
# ---> 30 mat = scipy.io.loadmat(mat_path)
#      31 signals = mat["val"].astype(np.float32)
#      32 if downsample_factor > 1:
#
# File c:\Users\IDMOP0\Documents\master\mHealth-project-code\.venv\Lib\site-packages\scipy\io\matlab\_mio.py:234, in loadmat(file_name, mdict, appendmat, spmatrix, **kwargs)
#      88 """
#      89 Load MATLAB file.
#      90
#    (...)    231     3.14159265+3.14159265j])
#     232 """
#     233 variable_names = kwargs.pop('variable_names', None)
# --> 234 with _open_file_context(file_name, appendmat) as f:
#     235     MR, _ = mat_reader_factory(f, **kwargs)
#     236     matfile_dict = MR.get_variables(variable_names)
#
# File ~\AppData\Local\Python\pythoncore-3.12-64\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\IDMOP0\Documents\master\mHealth-project-code\.venv\Lib\site-packages\scipy\io\matlab\_mio.py:17, in _open_file_context(file_like, appendmat, mode)
#      15 @contextmanager
#      16 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 17     f, opened = _open_file(file_like, appendmat, mode)
#      18     try:
#      19         yield f
#
# File c:\Users\IDMOP0\Documents\master\mHealth-project-code\.venv\Lib\site-packages\scipy\io\matlab\_mio.py:47, in _open_file(file_like, appendmat, mode)
#      45     return open(file_like, mode), True
#      46 else:
# ---> 47     raise OSError(
#      48         'Reader needs file name or open file-like object'
#      49     ) from e
#
# OSError: Reader needs file name or open file-like object
